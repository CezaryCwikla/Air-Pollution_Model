# %%
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns;


# %matplotlib inline

# For Data Preprocessing
from sklearn.preprocessing import LabelEncoder, MinMaxScaler

# For building the LSTM Model
from keras.models import Sequential
from keras.layers import LSTM, Dense

# For evaluating the model
from sklearn.metrics import mean_squared_error

data = pd.read_csv('Data/Pogodowe_i_powietrza_2020_10-2021_06.csv', sep=';')

# %%
data.dropna(inplace=True)

# %%
data_df = data

# %%
data_df = data_df.reset_index()
six_df = pd.DataFrame()
twelve_df = pd.DataFrame()
tf_df = pd.DataFrame()
for i in range(len(data_df)):
    six_df = pd.concat([six_df,pd.DataFrame({'PM2.5 6hr_avg':[sum(data_df['PM2.5'].iloc[i:i+6])/6]}, index = [i+6])])
    twelve_df = pd.concat([twelve_df,pd.DataFrame({'PM2.5 12hr_avg':[sum(data_df['PM2.5'].iloc[i:i+12])/12]}, index = [i+12])])
    tf_df = pd.concat([tf_df,pd.DataFrame({'PM2.5 24hr_avg':[sum(data_df['PM2.5'].iloc[i:i+24])/24]}, index = [i+24])])
   
data_df = pd.merge(data_df, six_df, left_index=True, right_index=True)
data_df = pd.merge(data_df, twelve_df, left_index=True, right_index=True)
data_df = pd.merge(data_df, tf_df, left_index=True, right_index=True)

# %%
data_df['H'] = pd.to_datetime(data_df['Time']).dt.time
data_df['H'] = data_df['H'].astype('string')

# %%
data_df['H'] = data_df['H'].str.replace(r'\D', '')
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_27864\4249282884.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   data_df['H'] = data_df['H'].str.replace(r'\D', '')

# %%
data_df['H'] = data_df['H'].str.replace(r'.{4}$', '')
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_27864\1843561337.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   data_df['H'] = data_df['H'].str.replace(r'.{4}$', '')

# %%
data_df['H'] = data_df['H'].astype('float')

# %%
data_df = data_df.drop('index', axis=1)
data_df = data_df.drop('Data', axis=1)
data_df = data_df.drop('Name', axis=1)
data_df['Time'] = pd.to_datetime(data_df['Time'], format='%Y%m%d %H')
data_df.index = data_df['Time']
data_df = data_df.drop('Time', axis=1)

# %%
data_df.head(15)
# Out:
#                   Time     Name  Precipitation  PrecipitationType  \
# 0  2020-10-04 05:00:00  ENV0353            0.0                0.0
# 1  2020-10-04 06:00:00  ENV0353            0.0                0.0
# 2  2020-10-04 08:00:00  ENV0353            0.0                0.0
# 3  2020-10-04 21:00:00  ENV0353            0.0                0.0
# 4  2020-10-04 23:00:00  ENV0353            0.0                0.0
# 5  2020-10-05 02:00:00  ENV0353            0.0                0.0
# 6  2020-10-05 03:00:00  ENV0353            0.0                0.0
# 7  2020-10-05 04:00:00  ENV0353            0.0                0.0
# 9  2020-10-06 04:00:00  ENV0353            0.0                0.0
# 10 2020-10-06 05:00:00  ENV0353            0.0                0.0
# 11 2020-10-06 07:00:00  ENV0353            0.0                0.0
# 12 2020-10-07 20:00:00  ENV0353            0.0                0.0
# 13 2020-10-07 22:00:00  ENV0353            0.0                0.0
# 14 2020-10-07 23:00:00  ENV0353            0.0                0.0
# 15 2020-10-08 20:00:00  ENV0353            0.0                0.0
#
#     AirTemperature  LaneTemperature  FreezingTemperature  DewpointTemperature  \
# 0       287.556817       288.263258               273.15           286.975185
# 1       287.107771       287.896579               273.15           286.656025
# 2       288.515379       289.026129               273.15           286.639987
# 3       289.066417       290.610318               273.15           284.473912
# 4       286.485905       288.977836               273.15           284.122151
# 5       285.954975       287.530611               273.15           283.759610
# 6       284.146597       286.946819               273.15           283.494526
# 7       284.102366       286.527513               273.15           283.860600
# 9       284.279010       286.315853               273.15           284.279011
# 10      283.870873       286.264965               273.15           283.870873
# 11      283.377186       286.143804               273.15           283.377186
# 12      286.296014       289.815497               273.15           285.054358
# 13      285.721697       288.935763               273.15           284.859169
# 14      285.768792       288.832995               273.15           284.749505
# 15      285.876284       288.099707               273.15           285.100541
#
#     DepthTemperatureTT1  DepthTemperatureTT3  ...  LaneWetness  Salt  \
# 0            289.849884           291.430685  ...          0.0   0.0
# 1            289.495106           291.367497  ...          0.0   0.0
# 2            289.209542           291.212204  ...          0.0   0.0
# 3            293.053505           292.854622  ...          0.0   0.0
# 4            291.632794           292.785160  ...          0.0   0.0
# 5            289.975392           292.468255  ...          0.0   0.0
# 6            289.502644           292.331517  ...          0.0   0.0
# 7            289.029433           292.185051  ...          0.0   0.0
# 9            288.577063           291.713654  ...          0.0   0.0
# 10           288.203944           291.589207  ...          0.0   0.0
# 11           287.765723           291.324778  ...          0.0   0.0
# 12           291.852810           291.897923  ...          0.0   0.0
# 13           290.597741           291.916619  ...          0.0   0.0
# 14           290.253584           291.876110  ...          0.0   0.0
# 15           288.908110           290.532219  ...          0.0   0.0
#
#                    Data  PM2.5  PM10  tlenek azotu  tlenki azotu  \
# 0   2020-10-04 05:00:00   15.2  23.9          17.4          47.7
# 1   2020-10-04 06:00:00   16.9  27.0          31.1          82.0
# 2   2020-10-04 08:00:00   14.2  23.5          20.2          54.2
# 3   2020-10-04 21:00:00    4.5  10.5           0.9          23.8
# 4   2020-10-04 23:00:00    6.4  12.4          42.1         112.8
# 5   2020-10-05 02:00:00    4.0   8.9           4.6          32.3
# 6   2020-10-05 03:00:00    5.6  11.0           5.7          41.6
# 7   2020-10-05 04:00:00    4.4   9.7          11.9          35.4
# 9   2020-10-06 04:00:00   19.5  28.2          28.7          70.2
# 10  2020-10-06 05:00:00   20.7  31.1          79.7         151.8
# 11  2020-10-06 07:00:00   18.7  31.1          91.0         174.4
# 12  2020-10-07 20:00:00   18.9  26.0          13.7          64.5
# 13  2020-10-07 22:00:00   20.7  27.2          13.5          63.8
# 14  2020-10-07 23:00:00   23.1  29.5           6.9          44.0
# 15  2020-10-08 20:00:00   33.0  43.0          30.5          89.0
#
#     tlenek węgla  benzen dwutlenek azotu
# 0            0.3     0.4            20.9
# 1            0.4     0.5            34.3
# 2            0.4     0.7            23.2
# 3            0.3     0.4            22.4
# 4            0.5     0.7            48.2
# 5            0.3     0.2            25.2
# 6            0.3     0.3            32.9
# 7            0.2     0.3            17.2
# 9            0.5     0.8            26.1
# 10           0.5     0.9            29.6
# 11           0.8     1.1            34.9
# 12           0.5     0.7            43.5
# 13           0.5     0.7            43.2
# 14           0.4     0.6            33.5
# 15           0.6     0.9            42.1
#
# [15 rows x 27 columns]

# %%
data_df.to_csv('obrobione.csv')

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
values = scaler.fit_transform(data_df)
data_df2 = pd.DataFrame(values)

# %%
data_df2.columns = data_df.columns
data_df2.index = data_df.index

# %%
data_df2.dropna(inplace=True)

# %%
dataset = np.log1p(data_df2[['PM2.5']].values)
dataset.shape
# Out:
# (7961, 1)

# %%
dist_df = pd.DataFrame({'PM10' : data_df2['PM10'].values, 'log_PM10' : dataset[:,0]})

# histogram plot original vs log transform data
plt.figure(figsize=(12,5))
dist_df.hist();

# %%
train_size = int(len(dataset) * 0.80)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]
print(len(train), len(test))
# Out:
# 6368 1593

# %%
def create_dataset(dataset, look_back=1):
    dataX, dataY = [], []
    for i in range(len(dataset)-look_back-1):
        a = dataset[i:(i+look_back), 0]
        dataX.append(a)
        dataY.append(dataset[i + look_back, 0])
    return np.array(dataX), np.array(dataY)

# %%
look_back = 1
trainX, trainY = create_dataset(train, look_back)
testX, testY = create_dataset(test, look_back)

print('Shape of trainX :', trainX.shape)
print('Shape of trainY :', trainY.shape)
print('Shape of testX :', testX.shape)
print('Shape of testY :', testY.shape)
# Out:
# Shape of trainX : (6366, 1)
# Shape of trainY : (6366,)
# Shape of testX : (1591, 1)
# Shape of testY : (1591,)

# %%
trainX = np.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
testX = np.reshape(testX, (testX.shape[0], 1, testX.shape[1]))

print('Shape of trainX :', trainX.shape)
print('Shape of testX :', testX.shape)
# Out:
# Shape of trainX : (6366, 1, 1)
# Shape of testX : (1591, 1, 1)

# %%
model = Sequential()
model.add(LSTM(4, input_shape=(1, look_back)))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')
model.fit(trainX, trainY, epochs=100, batch_size=32, verbose=2)
# Out:
# Epoch 1/100
# 199/199 - 2s - loss: 0.0041 - 2s/epoch - 11ms/step
# Epoch 2/100
# 199/199 - 0s - loss: 0.0031 - 486ms/epoch - 2ms/step
# Epoch 3/100
# 199/199 - 0s - loss: 0.0026 - 384ms/epoch - 2ms/step
# Epoch 4/100
# 199/199 - 0s - loss: 0.0018 - 393ms/epoch - 2ms/step
# Epoch 5/100
# 199/199 - 0s - loss: 0.0013 - 478ms/epoch - 2ms/step
# Epoch 6/100
# 199/199 - 1s - loss: 0.0011 - 515ms/epoch - 3ms/step
# Epoch 7/100
# 199/199 - 1s - loss: 0.0011 - 538ms/epoch - 3ms/step
# Epoch 8/100
# 199/199 - 1s - loss: 0.0011 - 513ms/epoch - 3ms/step
# Epoch 9/100
# 199/199 - 1s - loss: 0.0011 - 539ms/epoch - 3ms/step
# Epoch 10/100
# 199/199 - 1s - loss: 0.0011 - 566ms/epoch - 3ms/step
# Epoch 11/100
# 199/199 - 1s - loss: 0.0011 - 503ms/epoch - 3ms/step
# Epoch 12/100
# 199/199 - 1s - loss: 0.0011 - 532ms/epoch - 3ms/step
# Epoch 13/100
# 199/199 - 1s - loss: 0.0011 - 573ms/epoch - 3ms/step
# Epoch 14/100
# 199/199 - 1s - loss: 0.0011 - 531ms/epoch - 3ms/step
# Epoch 15/100
# 199/199 - 1s - loss: 0.0011 - 525ms/epoch - 3ms/step
# Epoch 16/100
# 199/199 - 1s - loss: 0.0011 - 522ms/epoch - 3ms/step
# Epoch 17/100
# 199/199 - 0s - loss: 0.0011 - 472ms/epoch - 2ms/step
# Epoch 18/100
# 199/199 - 0s - loss: 0.0011 - 448ms/epoch - 2ms/step
# Epoch 19/100
# 199/199 - 0s - loss: 0.0011 - 447ms/epoch - 2ms/step
# Epoch 20/100
# 199/199 - 0s - loss: 0.0011 - 447ms/epoch - 2ms/step
# Epoch 21/100
# 199/199 - 0s - loss: 0.0011 - 427ms/epoch - 2ms/step
# Epoch 22/100
# 199/199 - 0s - loss: 0.0011 - 433ms/epoch - 2ms/step
# Epoch 23/100
# 199/199 - 0s - loss: 0.0011 - 428ms/epoch - 2ms/step
# Epoch 24/100
# 199/199 - 0s - loss: 0.0011 - 440ms/epoch - 2ms/step
# Epoch 25/100
# 199/199 - 0s - loss: 0.0011 - 460ms/epoch - 2ms/step
# Epoch 26/100
# 199/199 - 0s - loss: 0.0011 - 449ms/epoch - 2ms/step
# Epoch 27/100
# 199/199 - 0s - loss: 0.0011 - 383ms/epoch - 2ms/step
# Epoch 28/100
# 199/199 - 0s - loss: 0.0011 - 454ms/epoch - 2ms/step
# Epoch 29/100
# 199/199 - 0s - loss: 0.0011 - 428ms/epoch - 2ms/step
# Epoch 30/100
# 199/199 - 0s - loss: 0.0011 - 345ms/epoch - 2ms/step
# Epoch 31/100
# 199/199 - 0s - loss: 0.0011 - 404ms/epoch - 2ms/step
# Epoch 32/100
# 199/199 - 0s - loss: 0.0011 - 402ms/epoch - 2ms/step
# Epoch 33/100
# 199/199 - 0s - loss: 0.0011 - 401ms/epoch - 2ms/step
# Epoch 34/100
# 199/199 - 0s - loss: 0.0011 - 431ms/epoch - 2ms/step
# Epoch 35/100
# 199/199 - 0s - loss: 0.0011 - 431ms/epoch - 2ms/step
# Epoch 36/100
# 199/199 - 0s - loss: 0.0011 - 305ms/epoch - 2ms/step
# Epoch 37/100
# 199/199 - 0s - loss: 0.0011 - 305ms/epoch - 2ms/step
# Epoch 38/100
# 199/199 - 0s - loss: 0.0011 - 315ms/epoch - 2ms/step
# Epoch 39/100
# 199/199 - 0s - loss: 0.0011 - 403ms/epoch - 2ms/step
# Epoch 40/100
# 199/199 - 0s - loss: 0.0011 - 410ms/epoch - 2ms/step
# Epoch 41/100
# 199/199 - 0s - loss: 0.0011 - 405ms/epoch - 2ms/step
# Epoch 42/100
# 199/199 - 0s - loss: 0.0011 - 399ms/epoch - 2ms/step
# Epoch 43/100
# 199/199 - 0s - loss: 0.0011 - 298ms/epoch - 1ms/step
# Epoch 44/100
# 199/199 - 0s - loss: 0.0011 - 376ms/epoch - 2ms/step
# Epoch 45/100
# 199/199 - 0s - loss: 0.0011 - 353ms/epoch - 2ms/step
# Epoch 46/100
# 199/199 - 0s - loss: 0.0011 - 410ms/epoch - 2ms/step
# Epoch 47/100
# 199/199 - 0s - loss: 0.0011 - 400ms/epoch - 2ms/step
# Epoch 48/100
# 199/199 - 0s - loss: 0.0011 - 388ms/epoch - 2ms/step
# Epoch 49/100
# 199/199 - 0s - loss: 0.0011 - 431ms/epoch - 2ms/step
# Epoch 50/100
# 199/199 - 0s - loss: 0.0011 - 325ms/epoch - 2ms/step
# Epoch 51/100
# 199/199 - 0s - loss: 0.0011 - 361ms/epoch - 2ms/step
# Epoch 52/100
# 199/199 - 0s - loss: 0.0011 - 315ms/epoch - 2ms/step
# Epoch 53/100
# 199/199 - 0s - loss: 0.0011 - 459ms/epoch - 2ms/step
# Epoch 54/100
# 199/199 - 0s - loss: 0.0011 - 470ms/epoch - 2ms/step
# Epoch 55/100
# 199/199 - 0s - loss: 0.0011 - 464ms/epoch - 2ms/step
# Epoch 56/100
# 199/199 - 0s - loss: 0.0011 - 443ms/epoch - 2ms/step
# Epoch 57/100
# 199/199 - 0s - loss: 0.0011 - 373ms/epoch - 2ms/step
# Epoch 58/100
# 199/199 - 0s - loss: 0.0011 - 424ms/epoch - 2ms/step
# Epoch 59/100
# 199/199 - 0s - loss: 0.0011 - 352ms/epoch - 2ms/step
# Epoch 60/100
# 199/199 - 0s - loss: 0.0011 - 391ms/epoch - 2ms/step
# Epoch 61/100
# 199/199 - 0s - loss: 0.0011 - 357ms/epoch - 2ms/step
# Epoch 62/100
# 199/199 - 0s - loss: 0.0011 - 472ms/epoch - 2ms/step
# Epoch 63/100
# 199/199 - 0s - loss: 0.0011 - 460ms/epoch - 2ms/step
# Epoch 64/100
# 199/199 - 0s - loss: 0.0011 - 478ms/epoch - 2ms/step
# Epoch 65/100
# 199/199 - 0s - loss: 0.0011 - 477ms/epoch - 2ms/step
# Epoch 66/100
# 199/199 - 0s - loss: 0.0011 - 321ms/epoch - 2ms/step
# Epoch 67/100
# 199/199 - 0s - loss: 0.0011 - 325ms/epoch - 2ms/step
# Epoch 68/100
# 199/199 - 0s - loss: 0.0011 - 356ms/epoch - 2ms/step
# Epoch 69/100
# 199/199 - 0s - loss: 0.0011 - 465ms/epoch - 2ms/step
# Epoch 70/100
# 199/199 - 0s - loss: 0.0011 - 472ms/epoch - 2ms/step
# Epoch 71/100
# 199/199 - 0s - loss: 0.0011 - 441ms/epoch - 2ms/step
# Epoch 72/100
# 199/199 - 0s - loss: 0.0011 - 443ms/epoch - 2ms/step
# Epoch 73/100
# 199/199 - 0s - loss: 0.0011 - 396ms/epoch - 2ms/step
# Epoch 74/100
# 199/199 - 0s - loss: 0.0011 - 388ms/epoch - 2ms/step
# Epoch 75/100
# 199/199 - 0s - loss: 0.0011 - 428ms/epoch - 2ms/step
# Epoch 76/100
# 199/199 - 0s - loss: 0.0011 - 421ms/epoch - 2ms/step
# Epoch 77/100
# 199/199 - 0s - loss: 0.0011 - 412ms/epoch - 2ms/step
# Epoch 78/100
# 199/199 - 0s - loss: 0.0011 - 415ms/epoch - 2ms/step
# Epoch 79/100
# 199/199 - 0s - loss: 0.0011 - 422ms/epoch - 2ms/step
# Epoch 80/100
# 199/199 - 0s - loss: 0.0011 - 418ms/epoch - 2ms/step
# Epoch 81/100
# 199/199 - 0s - loss: 0.0011 - 418ms/epoch - 2ms/step
# Epoch 82/100
# 199/199 - 0s - loss: 0.0011 - 420ms/epoch - 2ms/step
# Epoch 83/100
# 199/199 - 0s - loss: 0.0011 - 413ms/epoch - 2ms/step
# Epoch 84/100
# 199/199 - 0s - loss: 0.0011 - 407ms/epoch - 2ms/step
# Epoch 85/100
# 199/199 - 0s - loss: 0.0011 - 432ms/epoch - 2ms/step
# Epoch 86/100
# 199/199 - 0s - loss: 0.0011 - 396ms/epoch - 2ms/step
# Epoch 87/100
# 199/199 - 0s - loss: 0.0011 - 396ms/epoch - 2ms/step
# Epoch 88/100
# 199/199 - 0s - loss: 0.0011 - 397ms/epoch - 2ms/step
# Epoch 89/100
# 199/199 - 0s - loss: 0.0011 - 395ms/epoch - 2ms/step
# Epoch 90/100
# 199/199 - 0s - loss: 0.0011 - 402ms/epoch - 2ms/step
# Epoch 91/100
# 199/199 - 0s - loss: 0.0011 - 401ms/epoch - 2ms/step
# Epoch 92/100
# 199/199 - 0s - loss: 0.0011 - 401ms/epoch - 2ms/step
# Epoch 93/100
# 199/199 - 0s - loss: 0.0011 - 397ms/epoch - 2ms/step
# Epoch 94/100
# 199/199 - 0s - loss: 0.0011 - 409ms/epoch - 2ms/step
# Epoch 95/100
# 199/199 - 0s - loss: 0.0011 - 362ms/epoch - 2ms/step
# Epoch 96/100
# 199/199 - 1s - loss: 0.0011 - 556ms/epoch - 3ms/step
# Epoch 97/100
# 199/199 - 0s - loss: 0.0011 - 438ms/epoch - 2ms/step
# Epoch 98/100
# 199/199 - 0s - loss: 0.0011 - 347ms/epoch - 2ms/step
# Epoch 99/100
# 199/199 - 0s - loss: 0.0011 - 337ms/epoch - 2ms/step
# Epoch 100/100
# 199/199 - 0s - loss: 0.0011 - 329ms/epoch - 2ms/step

# %%
trainPredict = model.predict(trainX)
testPredict = model.predict(testX)

# invert predictions
trainPredict = np.expm1(trainPredict)
trainY = np.expm1(trainY)
testPredict = np.expm1(testPredict)
testY = np.expm1(testY)

# calculate root mean squared error
trainScore = math.sqrt(mean_squared_error(trainY, trainPredict[:,0]))
print('Train Score: %.2f RMSE' % (trainScore))
testScore = math.sqrt(mean_squared_error(testY, testPredict[:,0]))
print('Test Score: %.2f RMSE' % (testScore))
# Out:
# Train Score: 0.04 RMSE
# Test Score: 0.05 RMSE

# %%
test_series = pd.Series(testY)

# state of model performance
if testScore < test_series.std():
    print('\n[ Model performance is GOOD enough ]')
    print('\nRMSE of test prediction < Standard deviation of test dataset')
    print('%.2f' % (testScore), '<', '%.2f' % (test_series.std()))
else:
    print('\n[ Model performance is NOT GOOD enough ]')
    print('\nRMSE of test prediction > Standard deviation of test dataset')
    print('%.2f' % (testScore), '>', '%.2f' % (test_series.std()))
# Out:
# [ Model performance is GOOD enough ]
#
# RMSE of test prediction < Standard deviation of test dataset
# 0.05 < 0.08

# %%
# shift train predictions for plotting
trainPredictPlot = np.empty_like(dataset)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back:len(trainPredict)+look_back, :] = trainPredict

# shift test predictions for plotting
testPredictPlot = np.empty_like(dataset)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(trainPredict)+(look_back*2)+1:len(dataset)-1, :] = testPredict

# plot original dataset and predictions
time_axis = np.linspace(0, dataset.shape[0]-1, 15)
time_axis = np.array([int(i) for i in time_axis])
time_axisLab = np.array(data_df.index, dtype='datetime64[D]')

fig = plt.figure()
ax = fig.add_axes([0, 0, 2.1, 2])
ax.plot(np.expm1(dataset), label='Original Dataset')
ax.plot(trainPredictPlot, color='orange', label='Train Prediction')
ax.plot(testPredictPlot, color='red', label='Test Prediction')
ax.set_xticks(time_axis)
ax.set_xticklabels(time_axisLab[time_axis], rotation=45)
ax.set_xlabel('\nDate', fontsize=27, fontweight='bold')
ax.set_ylabel('PM2.5', fontsize=27, fontweight='bold')
ax.legend(loc='best', prop= {'size':20})
ax.tick_params(size=10, labelsize=15)
ax.set_xlim([-1,1735])

ax1 = fig.add_axes([2.3, 1.3, 1, 0.7])
ax1.plot(np.expm1(dataset), label='Original Dataset')
ax1.plot(testPredictPlot, color='red', label='Test Prediction')
ax1.set_xticks(time_axis)
ax1.set_xticklabels(time_axisLab[time_axis], rotation=45)
ax1.set_xlabel('Date', fontsize=27, fontweight='bold')
ax1.set_ylabel('PM2.5', fontsize=27, fontweight='bold')
ax1.tick_params(size=10, labelsize=15)
ax1.set_xlim([1360,1735]);

# %%
correlations = data_df.corr()
fig, ax = plt.subplots(figsize=(15,15))
sns.heatmap(correlations, vmax=1.0, center=0, fmt='.2f', square=True, linewidths=.5, annot=True, cbar_kws={"shrink": .70})
plt.show();

# %%
sns.jointplot(x=data_df['Precipitation'], y=data_df['PM2.5'], data = data_df)

# %%
data_df
# Out:
#       index                Time     Name  Precipitation  PrecipitationType  \
# 24       26 2020-10-10 04:00:00  ENV0353            0.0                0.0
# 25       27 2020-10-10 05:00:00  ENV0353            0.0                0.0
# 26       28 2020-10-10 06:00:00  ENV0353            0.0                0.0
# 27       29 2020-10-10 07:00:00  ENV0353            0.0                0.0
# 28       31 2020-10-10 23:00:00  ENV0353            0.0                0.0
# ...     ...                 ...      ...            ...                ...
# 7980   8756 2021-04-14 02:00:00  ENV0353            0.0                0.0
# 7981   8757 2021-04-14 05:00:00  ENV0353            0.0                0.0
# 7982   8758 2021-04-14 06:00:00  ENV0353            0.0               70.0
# 7983   8759 2021-04-14 08:00:00  ENV0353            0.0                0.0
# 7984   8760 2021-04-14 09:00:00  ENV0353            0.0                0.0
#
#       AirTemperature  LaneTemperature  FreezingTemperature  \
# 24        283.165346       285.531589               273.15
# 25        282.793536       285.391513               273.15
# 26        282.529349       285.125956               273.15
# 27        282.435589       285.156699               273.15
# 28        286.915612       288.997163               273.15
# ...              ...              ...                  ...
# 7980      273.307877       274.642543               273.05
# 7981      273.237075       274.221729               273.05
# 7982      273.095751       273.674892               273.05
# 7983      273.230116       275.067562               273.05
# 7984      273.262069       276.180322               273.05
#
#       DewpointTemperature  DepthTemperatureTT1  ...  PM2.5  PM10  \
# 24             283.165345           287.417578  ...   16.4  24.0
# 25             282.793536           287.107990  ...   16.7  24.7
# 26             282.529348           286.901892  ...   16.3  24.6
# 27             282.435590           286.686826  ...   16.0  24.7
# 28             285.923917           289.883162  ...   35.7  45.2
# ...                   ...                  ...  ...    ...   ...
# 7980           273.307877           278.671641  ...   10.4  13.8
# 7981           273.237075           277.610011  ...    4.8   8.1
# 7982           273.095751           277.190609  ...    5.0   8.4
# 7983           273.230116           276.821600  ...    6.3  10.2
# 7984           273.262069           277.151465  ...    5.1   8.6
#
#       tlenek azotu  tlenki azotu  tlenek węgla  benzen  dwutlenek azotu  \
# 24             5.5          22.8           0.4     0.8             14.2
# 25            20.3          46.8           0.5     0.8             15.6
# 26            20.9          46.0           0.5     0.8             13.9
# 27            41.8          80.1           0.6     0.8             16.0
# 28            10.7          48.7           0.7     1.6             32.2
# ...            ...           ...           ...     ...              ...
# 7980           0.4           8.9           0.2     0.5              8.6
# 7981          16.9          37.8           0.3     0.4             26.7
# 7982          31.3          67.6           0.4     0.4             47.2
# 7983          33.4          72.5           0.4     0.7             50.6
# 7984          21.2          53.1           0.3     0.8             39.2
#
#       PM2.5 6hr_avg  PM2.5 12hr_avg  PM2.5 24hr_avg
# 24        29.050000       30.158333       21.287500
# 25        26.133333       29.800000       21.337500
# 26        26.083333       29.266667       21.329167
# 27        22.266667       27.875000       21.416667
# 28        19.400000       26.191667       21.895833
# ...             ...             ...             ...
# 7980      29.533333       36.250000       36.941667
# 7981      24.533333       32.950000       36.525000
# 7982      22.016667       28.858333       35.750000
# 7983      12.300000       25.791667       34.929167
# 7984       8.316667       22.316667       34.279167
#
# [7961 rows x 31 columns]

# %%
sns.jointplot(x=data_df['PM2.5 6hr_avg'], y=data_df['PM2.5'], data = data_df)

# %%
sns.jointplot(x=data_df['PM10'], y=data_df['PM2.5'], data = data_df)

# %%
data['Time'] = pd.to_datetime(data['Time'], format='%Y%m%d %H')
data.groupby(pd.to_datetime(data['Time']).dt.hour).count()
# Out:
#       Time  Name  Precipitation  PrecipitationType  AirTemperature  \
# Time
# 0      338   338            338                338             338
# 1      337   337            337                337             337
# 2      337   337            337                337             337
# 3      337   337            337                337             337
# 4      337   337            337                337             337
# 5      338   338            338                338             338
# 6      337   337            337                337             337
# 7      339   339            339                339             339
# 8      337   337            337                337             337
# 9      336   336            336                336             336
# 10     334   334            334                334             334
# 11     332   332            332                332             332
# 12     336   336            336                336             336
# 13     335   335            335                335             335
# 14     334   334            334                334             334
# 15     338   338            338                338             338
# 16     340   340            340                340             340
# 17     341   341            341                341             341
# 18     340   340            340                340             340
# 19     224   224            224                224             224
# 20     340   340            340                340             340
# 21     340   340            340                340             340
# 22     339   339            339                339             339
# 23     339   339            339                339             339
#
#       LaneTemperature  FreezingTemperature  DewpointTemperature  \
# Time
# 0                 338                  338                  338
# 1                 337                  337                  337
# 2                 337                  337                  337
# 3                 337                  337                  337
# 4                 337                  337                  337
# 5                 338                  338                  338
# 6                 337                  337                  337
# 7                 339                  339                  339
# 8                 337                  337                  337
# 9                 336                  336                  336
# 10                334                  334                  334
# 11                332                  332                  332
# 12                336                  336                  336
# 13                335                  335                  335
# 14                334                  334                  334
# 15                338                  338                  338
# 16                340                  340                  340
# 17                341                  341                  341
# 18                340                  340                  340
# 19                224                  224                  224
# 20                340                  340                  340
# 21                340                  340                  340
# 22                339                  339                  339
# 23                339                  339                  339
#
#       DepthTemperatureTT1  DepthTemperatureTT3  ...  LaneWetness  Salt  Data  \
# Time                                            ...
# 0                     338                  338  ...          338   338   338
# 1                     337                  337  ...          337   337   337
# 2                     337                  337  ...          337   337   337
# 3                     337                  337  ...          337   337   337
# 4                     337                  337  ...          337   337   337
# 5                     338                  338  ...          338   338   338
# 6                     337                  337  ...          337   337   337
# 7                     339                  339  ...          339   339   339
# 8                     337                  337  ...          337   337   337
# 9                     336                  336  ...          336   336   336
# 10                    334                  334  ...          334   334   334
# 11                    332                  332  ...          332   332   332
# 12                    336                  336  ...          336   336   336
# 13                    335                  335  ...          335   335   335
# 14                    334                  334  ...          334   334   334
# 15                    338                  338  ...          338   338   338
# 16                    340                  340  ...          340   340   340
# 17                    341                  341  ...          341   341   341
# 18                    340                  340  ...          340   340   340
# 19                    224                  224  ...          224   224   224
# 20                    340                  340  ...          340   340   340
# 21                    340                  340  ...          340   340   340
# 22                    339                  339  ...          339   339   339
# 23                    339                  339  ...          339   339   339
#
#       PM2.5  PM10  tlenek azotu  tlenki azotu  tlenek węgla  benzen  \
# Time
# 0       338   338           338           338           338     338
# 1       337   337           337           337           337     337
# 2       337   337           337           337           337     337
# 3       337   337           337           337           337     337
# 4       337   337           337           337           337     337
# 5       338   338           338           338           338     338
# 6       337   337           337           337           337     337
# 7       339   339           339           339           339     339
# 8       337   337           337           337           337     337
# 9       336   336           336           336           336     336
# 10      334   334           334           334           334     334
# 11      332   332           332           332           332     332
# 12      336   336           336           336           336     336
# 13      335   335           335           335           335     335
# 14      334   334           334           334           334     334
# 15      338   338           338           338           338     338
# 16      340   340           340           340           340     340
# 17      341   341           341           341           341     341
# 18      340   340           340           340           340     340
# 19      224   224           224           224           224     224
# 20      340   340           340           340           340     340
# 21      340   340           340           340           340     340
# 22      339   339           339           339           339     339
# 23      339   339           339           339           339     339
#
#       dwutlenek azotu
# Time
# 0                 338
# 1                 337
# 2                 337
# 3                 337
# 4                 337
# 5                 338
# 6                 337
# 7                 339
# 8                 337
# 9                 336
# 10                334
# 11                332
# 12                336
# 13                335
# 14                334
# 15                338
# 16                340
# 17                341
# 18                340
# 19                224
# 20                340
# 21                340
# 22                339
# 23                339
#
# [24 rows x 27 columns]

# %%
sns.jointplot(x=data_df['Time'], y=data_df['PM2.5'], data = data_df)

# %%
temp_df = pd.DataFrame()
for i in range(len(data_df)):
    temp_df = pd.concat([temp_df,pd.DataFrame({'PM2.5 6hr_avg':[sum(data_df['AirTemperature'].iloc[i:i+6])/6]}, index = [i+6])]) 
data_df = pd.merge(data_df, six_df, left_index=True, right_index=True)
